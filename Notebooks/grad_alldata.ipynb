# %%
pip install emojis
# Out:
# Collecting emojis
#   Downloading emojis-0.7.0-py3-none-any.whl.metadata (3.5 kB)
# Downloading emojis-0.7.0-py3-none-any.whl (28 kB)
# Installing collected packages: emojis
# Successfully installed emojis-0.7.0

# %%
pip install tashaphyne
# Out:
# Collecting tashaphyne
#   Downloading Tashaphyne-0.3.6-py3-none-any.whl.metadata (18 kB)
# Collecting pyarabic (from tashaphyne)
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from pyarabic->tashaphyne) (1.17.0)
# Downloading Tashaphyne-0.3.6-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.5/251.5 kB 10.7 MB/s eta 0:00:00
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 14.9 MB/s eta 0:00:00
# Installing collected packages: pyarabic, tashaphyne
# Successfully installed pyarabic-0.6.15 tashaphyne-0.3.6

# %%
import pandas as pd
import sys

# %%
from google.colab import userdata
token = userdata.get('HF_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-6-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
sys.path.append('/content/drive/MyDrive')

# %%
splits = {'train': 'data/train-00000-of-00001.parquet', 'validation': 'data/validation-00000-of-00001.parquet', 'test': 'data/test-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/Abdelrahman-Rezk/Arabic_Dialect_Identification/" + splits["train"])

# %%
df.to_csv("dataset.csv", index=False, encoding='utf8')

# %%
df
# Out:
#                          id  label  \
# 0       1046024946705735552      9
# 1       1140189387508134016     17
# 2       1051416181855440768      0
# 3        781770259422412800     11
# 4        968140551366340608     11
# ...                     ...    ...
# 440047  1024415002810306560      6
# 440048   825422832138067968      3
# 440049  1137082760726810624      2
# 440050  1075003837436575616     11
# 440051  1072373084320120832      4
#
#                                                      text
# 0       @Ahmed_Hamza27 اتمنى صراحة و خصوصا #طال_عمره ب...
# 1       @rJiM4CnIFTgml9g @zamnissi طبعا عرفته من اللي ...
# 2       @OmanisFollowers @ooredoo @TRA_OMAN @motc_om ه...
# 3       كلب شو كنتوا بتتوقعوا منه !؟ \n\nمحمود عباس لا...
# 4                       #عزام 🔊\nاحنا ابو الولد وام الولد
# ...                                                   ...
# 440047  انت مش مجبور تجامل حدا وتعطيه اكبر من حجمه ؛ ع...
# 440048  رتم الفريق بدون جيرو سريييييييييع ، مع جيرو يص...
# 440049  🇸🇦💚🇸🇦💚🇸🇦\nksa\n👆🏻\nوغير هالبلد قلبي ما عشق ولا...
# 440050  @a7lawa7di @ranim2298 خلص اذا هيييك بطلت ادعي ...
# 440051  @aalsubaie___ @Ahmedhalyami90 خيولي هالدلوع مر...
#
# [440052 rows x 3 columns]

# %%
جميل

# %%
validation = pd.read_parquet("hf://datasets/Abdelrahman-Rezk/Arabic_Dialect_Identification/" + splits["validation"])
validation
# Out:
#                        id  label  \
# 0      910595516496515200      3
# 1      847921262752129024      6
# 2     1138977052055560192     10
# 3      978901748604645376     15
# 4      838068478179430400      3
# ...                   ...    ...
# 9159  1154583936523284480      3
# 9160  1139550319241773056      3
# 9161  1004448814609129600     11
# 9162  1122824694229553152     13
# 9163  1155877024000630784      2
#
#                                                    text
# 0     @A_E_92 استاذ عبدالعزيز  صارله الموضوع سنه يعن...
# 1     #كذبة_نيسان كل عام والكذاب بألف خير 🙈😂 https:/...
# 2                     @basitooo5 طمطم عاااتى طبق جبنة 🙄
# 3     @alsyasiyeh @alsyaaf يمكن متلاحقين السوق بيشتر...
# 4     @A_A_AlTammar عيل المدرب حمار حشاك .. مالها حل...
# ...                                                 ...
# 9159  @mohdfheed الله يشافيه ويعافيه ويكتب اجرك يبو ...
# 9160  @Naifalnemah تعال شوفني احسن من الفلم الهندي \...
# 9161  النااس اللي بتبني جديد \nقبل ما تعملوا تمديدات...
# 9162         @allyaa24 كثروا مثل الذبان في موسم الصيف🙂💔
# 9163  العمل اللي قام به منصور بن مشعل حتى\nالان مايخ...
#
# [9164 rows x 3 columns]

# %%
test = pd.read_parquet("hf://datasets/Abdelrahman-Rezk/Arabic_Dialect_Identification/" + splits["test"])
test
# Out:
#                        id  label  \
# 0     1159906099585327104     10
# 1      950123809608171648     14
# 2     1091295506960142336      2
# 3     1179845110718181376     14
# 4     1011983655546302464     10
# ...                   ...    ...
# 8976  1141240000253759616      5
# 8977   504915500737232896      1
# 8978  1063264861029891968      0
# 8979   898279689558667264     10
# 8980  1162463106989207552      3
#
#                                                    text
# 0     ايه الخيبة و الهرتلة قدام الجون دول؟؟ 🤪😲\nالعي...
# 1            @FIA_WIS تذكرت ما اسمي عائشة انا اسمي خولة
# 2     @showqiy @3nood_mh لا والله نروح نشجع قطر و نف...
# 3                    @espoir_dz1 يسلملي قلبك ولد مدينتي
# 4     ملخص مؤتمر أبو سبوبة، قصدي أبو ريدة....احنا عم...
# ...                                                 ...
# 8976                 وجدّي كان يطحن للحي\n\nقمح وسهريات
# 8977  الشي البضحك ويفقع المرارة انو كل دين سياسة منه...
# 8978  @alkalbani2007 مجرد تمني....وهذا متاح ومسموح.\...
# 8979  نسي يقول صوت رنه ال messenger 😂 https://t.co/R...
# 8980  @6wee6er @aaaaaaa48517879 @m3aly_alwazera هههه...
#
# [8981 rows x 3 columns]

# %%
validation.to_csv("validation.csv", index=False, encoding="utf8")
test.to_csv("test.csv", index=False, encoding="utf8")

# %%
from preprocessing_data import *

id_col = "id"
dialects_col = "label"
text_c = "text"
original_file = "/content/dataset.csv"
test_file = "/content/test.csv"
validation_file = "/content/validation.csv"
saved_file = "dataset_preprocessed.csv"
_ = arabic_preprocess_pipline(original_file, saved_file, id_col, text_c, dialects_col, labels_encoded=False ,using_lemma=False)
# Out:
# Number of instances in the file are:  440052
# Some samples of text after preprocessed it:
# ['حسابشخصي اتمني صراحه و خصوصا #طال_عمره بينا وبينه قصه عشق قديمه 😍 ', 'حسابشخصي حسابشخصي طبعا عرفته من اللي بشعار الليڤر', 'حسابشخصي حسابشخصي حسابشخصي حسابشخصي هيه هيه م يتغير شي . . كلهم ع بعضهم متولفين 😪 . . بيجيك مدير فرع قريب منك عشان يتساعد معك عشان بس يثبت جدارته لوظيفيه فكرسيه ويحاول يتعاون معك لكن فالنهايه بترجع ع نفس المشكله والدائره تدور لا بيقدموا ولا بياخروا 😪 . . وحدي غاسله ايدي منهم', 'كلب شو كنتوا بتتوقعوا منه ! ؟ محمود عباس لا يمثل الا نفسه . ', '#عزام 🔊 احنا ابو الولد وام الولد']
# ==================================================
# Number of instances in our new file are:  440052
# ==================================================
# Our Arabic preprocess pipeline is work without any error.

# %%
original_file = validation_file
saved_file2 = "valdataset_preprocessed.csv"
_ = arabic_preprocess_pipline(original_file, saved_file2, id_col, text_c, dialects_col, labels_encoded=False, using_lemma=False)
val_dataset = pd.read_csv(saved_file2)
# Out:
# Number of instances in the file are:  9164
# Some samples of text after preprocessed it:
# ['حسابشخصي استاذ عبدالعزيز صارله الموضوع سنه يعني متي اراجع التامينات', '#كذبه_نيسان كل عام والكذاب بالف خير 😂 رابطويب', 'حسابشخصي طمطم عااتي طبق جبنه 🙄 ', 'حسابشخصي حسابشخصي يمكن متلاحقين السوق بيشترون سمك للغداء 😋 ', 'حسابشخصي عيل المدرب حمار حشاك . . مالها حل ثالث . هم بعد صح كلامك الاحتمال الثاني واارد جداا 🤔 ']
# ==================================================
# Number of instances in our new file are:  9164
# ==================================================
# Our Arabic preprocess pipeline is work without any error.

# %%
new_dataset = pd.read_csv(saved_file)
new_dataset
# Out:
#                          id dialect  dialect_l_encoded  \
# 0       1046024946705735552      MA                  9
# 1       1140189387508134016      YE                 17
# 2       1051416181855440768      AE                  0
# 3        781770259422412800      PL                 11
# 4        968140551366340608      PL                 11
# ...                     ...     ...                ...
# 440047  1024415002810306560      KW                  6
# 440048   825422832138067968      EG                  3
# 440049  1137082760726810624      DZ                  2
# 440050  1075003837436575616      PL                 11
# 440051  1072373084320120832      IQ                  4
#
#                                                      text
# 0       حسابشخصي اتمني صراحه و خصوصا #طال_عمره بينا وب...
# 1       حسابشخصي حسابشخصي طبعا عرفته من اللي بشعار الليڤر
# 2       حسابشخصي حسابشخصي حسابشخصي حسابشخصي هيه هيه م ...
# 3       كلب شو كنتوا بتتوقعوا منه ! ؟ محمود عباس لا يم...
# 4                        #عزام 🔊 احنا ابو الولد وام الولد
# ...                                                   ...
# 440047  انت مش مجبور تجامل حدا وتعطيه اكبر من حجمه ؛ ع...
# 440048  رتم الفريق بدون جيرو سرييع ، مع جيرو يصير بطيي...
# 440049   🇸🇦 ksa 👆 🏻 وغير هالبلد قلبي ما عشق ولا راح يع...
# 440050  حسابشخصي حسابشخصي خلص اذا هييك بطلت ادعي واعطي...
# 440051  حسابشخصي حسابشخصي خيولي هالدلوع مره زين عشره ز...
#
# [440052 rows x 4 columns]

# %%
new_dataset.head()
# Out:
#                     id dialect  dialect_l_encoded  \
# 0  1046024946705735552      MA                  9
# 1  1140189387508134016      YE                 17
# 2  1051416181855440768      AE                  0
# 3   781770259422412800      PL                 11
# 4   968140551366340608      PL                 11
#
#                                                 text
# 0  حسابشخصي اتمني صراحه و خصوصا #طال_عمره بينا وب...
# 1  حسابشخصي حسابشخصي طبعا عرفته من اللي بشعار الليڤر
# 2  حسابشخصي حسابشخصي حسابشخصي حسابشخصي هيه هيه م ...
# 3  كلب شو كنتوا بتتوقعوا منه ! ؟ محمود عباس لا يم...
# 4                   #عزام 🔊 احنا ابو الولد وام الولد

# %%
val_dataset
# Out:
#                        id dialect  dialect_l_encoded  \
# 0      910595516496515200      EG                  3
# 1      847921262752129024      KW                  6
# 2     1138977052055560192      OM                 10
# 3      978901748604645376      SY                 15
# 4      838068478179430400      EG                  3
# ...                   ...     ...                ...
# 9159  1154583936523284480      EG                  3
# 9160  1139550319241773056      EG                  3
# 9161  1004448814609129600      PL                 11
# 9162  1122824694229553152      SA                 13
# 9163  1155877024000630784      DZ                  2
#
#                                                    text
# 0     حسابشخصي استاذ عبدالعزيز صارله الموضوع سنه يعن...
# 1         #كذبه_نيسان كل عام والكذاب بالف خير 😂 رابطويب
# 2                       حسابشخصي طمطم عااتي طبق جبنه 🙄
# 3     حسابشخصي حسابشخصي يمكن متلاحقين السوق بيشترون ...
# 4     حسابشخصي عيل المدرب حمار حشاك . . مالها حل ثال...
# ...                                                 ...
# 9159   حسابشخصي الله يشافيه ويعافيه ويكتب اجرك يبو فهيد
# 9160  حسابشخصي تعال شوفني احسن من الفلم الهندي لك وح...
# 9161  الناس اللي بتبني جديد قبل ما تعملوا تمديدات ال...
# 9162         حسابشخصي كثروا مثل الذبان في موسم الصيف 💔
# 9163  العمل اللي قام به منصور بن مشعل حتي الان مايخت...
#
# [9164 rows x 4 columns]

# %%
val_dataset.head()
# Out:
#                     id dialect  dialect_l_encoded  \
# 0   910595516496515200      EG                  3
# 1   847921262752129024      KW                  6
# 2  1138977052055560192      OM                 10
# 3   978901748604645376      SY                 15
# 4   838068478179430400      EG                  3
#
#                                                 text
# 0  حسابشخصي استاذ عبدالعزيز صارله الموضوع سنه يعن...
# 1      #كذبه_نيسان كل عام والكذاب بالف خير 😂 رابطويب
# 2                    حسابشخصي طمطم عااتي طبق جبنه 🙄
# 3  حسابشخصي حسابشخصي يمكن متلاحقين السوق بيشترون ...
# 4  حسابشخصي عيل المدرب حمار حشاك . . مالها حل ثال...

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)

# %%
# from sklearn.model_selection import StratifiedShuffleSplit

# x = newdataset.drop("dialect_l_encoded", axis=1)
# y = newdataset["dialect_l_encoded"]

# # Define StratifiedShuffleSplit
# split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
# for train_idx, temp_idx in split.split(x, y):
#     x_train, x_temp = x.iloc[train_idx], x.iloc[temp_idx]
#     y_train, y_temp = y.iloc[train_idx], y.iloc[temp_idx]

# # Splitting temp into validation and test
# split2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
# for val_idx, test_idx in split2.split(x_temp, y_temp):
#     x_val, x_test = x_temp.iloc[val_idx], x_temp.iloc[test_idx]
#     y_val, y_test = y_temp.iloc[val_idx], y_temp.iloc[test_idx]

# # Extract text for training and validation
# x_train = x_train["text"].reset_index(drop=True)
# x_val = x_val["text"].reset_index(drop=True)

# print(f"Number of data to train: {len(x_train)}")
# print(f"Number of data to validate: {len(x_val)}")
# print(f"Number of labels to train: {len(y_train)}")
# print(f"Number of labels to validate: {len(y_val)}")

# %% [markdown]
# Average words in a tweet

# %%
sum = 0
for text in new_dataset["text"]:
    sum += len(str(text).split())
avg = sum / len(new_dataset["text"])
avg
# Out:
# 15.961004608546263

# %% [markdown]
# Loading dataset

# %%
new_dataset = pd.read_csv("/content/drive/MyDrive/text dataset/dataset_preprocessed.csv")
# val_dataset = pd.read_csv("/content/valdataset_preprocessed.csv")

# %% [markdown]
# Prepare data to train

# %%
from sklearn.model_selection import StratifiedShuffleSplit

x = new_dataset.drop("dialect_l_encoded", axis=1)
y = new_dataset["dialect_l_encoded"]

# Define StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, temp_idx in split.split(x, y):
    x_train, x_temp = x.iloc[train_idx], x.iloc[temp_idx]
    y_train, y_temp = y.iloc[train_idx], y.iloc[temp_idx]

# Splitting temp into validation and test
split2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
for val_idx, test_idx in split2.split(x_temp, y_temp):
    x_val, x_test = x_temp.iloc[val_idx], x_temp.iloc[test_idx]
    y_val, y_test = y_temp.iloc[val_idx], y_temp.iloc[test_idx]

x_train_text = x_train["text"].reset_index(drop=True)
x_val_text = x_val["text"].reset_index(drop=True)

print(f"Number of data to train: {len(x_train)}")
print(f"Number of data to validate: {len(x_val)}")
print(f"Number of labels to train: {len(y_train)}")
print(f"Number of labels to validate: {len(y_val)}")
# Out:
# Number of data to train: 352041
# Number of data to validate: 44005
# Number of labels to train: 352041
# Number of labels to validate: 44005

# %%
x_train_text.head()
# Out:
# 0    حسابشخصي هذا كان بالجنوب حطه علم لانفصالين ودخ...
# 1    حسابشخصي حسابشخصي السعادهمالهادخل في الوظيفهمو...
# 2    حسابشخصي اللي بيسكر وبعدها بوقف بالشاعر يطخ عا...
# 3                        حسابشخصي نيالك قديه بالك طويل
# 4      حسابشخصي قال لحم العجل ازكي . . ايش جاب لجاب 😂
# Name: text, dtype: object

# %%
x_val_text.head()
# Out:
# 0                    حسابشخصي ما بجيبا الا الزحلاوي هه
# 1    حسابشخصي حسابشخصي شكلك هبله وبتستهبلي علينا وف...
# 2                   حسابشخصي 👍 اوا الله يجيب اللي يفهم
# 3    #بلا_تشفير هلا بس تحطوا بالتابوت بدو يقول عفوك...
# 4    ساعات بحس اني عايشه مع بقر بس متهيا لي البقر ب...
# Name: text, dtype: object

# %%
def display_text_before_tokenization(text_list):
  before_tokenization = []
  for sentence in text_list[:4]:
    before_tokenization.append(sentence)
  print("Text before tokenization")
  print(before_tokenization)

# %% [markdown]
# Tokenization and stemming

# %%
from nltk.tokenize import TreebankWordTokenizer

def treebank_tokenization(text_list):
  display_text_before_tokenization(text_list)
  tree_tokenizer = TreebankWordTokenizer()
  tokenized_text = []
  for text in text_list:
    tokenized_text.append(tree_tokenizer.tokenize(text))
  print("Text after tokenization")
  print(tokenized_text[:4])
  return tokenized_text

# %%
from tashaphyne.stemming import ArabicLightStemmer

def arabic_porter_stemmer(text_list):
  stemmed_text = []
  for text in text_list:
    stemmed_sentence = []
    for word in text:
      Arabic_stemmer = ArabicLightStemmer()
      Arabic_stemmer.light_stem(word)
      stemmed_sentence.append(Arabic_stemmer.get_stem())
    stemmed_text.append(stemmed_sentence)

  print("before")
  print(text_list[:4])
  print("after")
  print(stemmed_text[:4])

# %%
tokenized_train_text = treebank_tokenization(x_train_text)
tokenized_val_text = treebank_tokenization(x_val_text)
# Out:
# Text before tokenization
# ['حسابشخصي هذا كان بالجنوب حطه علم لانفصالين ودخل الشمال حط علم اليمن ممكن عشان مايتعرض للمشاكل', 'حسابشخصي حسابشخصي السعادهمالهادخل في الوظيفهمو حلو الشخص يعيش بدون استقرارمادي،العطاله تجيب الهم والتفكيروالايام تمشي بسرعهبدون مايحس فيهاجربت العطاله 3 سنوات ماتحملت مع اني لي مصروف وانام علي كيفي وماوراي اشغال بس برضو مافي احساس بالراحهذحين ادرس اشغل نفسي واخفف من الكابهاللي كنت احس فيها', 'حسابشخصي اللي بيسكر وبعدها بوقف بالشاعر يطخ عالناس بيستاهل خازوق عثماني، ما في اي وجه للمقارنه . . ', 'حسابشخصي نيالك قديه بالك طويل']
# Text after tokenization
# [['حسابشخصي', 'هذا', 'كان', 'بالجنوب', 'حطه', 'علم', 'لانفصالين', 'ودخل', 'الشمال', 'حط', 'علم', 'اليمن', 'ممكن', 'عشان', 'مايتعرض', 'للمشاكل'], ['حسابشخصي', 'حسابشخصي', 'السعادهمالهادخل', 'في', 'الوظيفهمو', 'حلو', 'الشخص', 'يعيش', 'بدون', 'استقرارمادي،العطاله', 'تجيب', 'الهم', 'والتفكيروالايام', 'تمشي', 'بسرعهبدون', 'مايحس', 'فيهاجربت', 'العطاله', '3', 'سنوات', 'ماتحملت', 'مع', 'اني', 'لي', 'مصروف', 'وانام', 'علي', 'كيفي', 'وماوراي', 'اشغال', 'بس', 'برضو', 'مافي', 'احساس', 'بالراحهذحين', 'ادرس', 'اشغل', 'نفسي', 'واخفف', 'من', 'الكابهاللي', 'كنت', 'احس', 'فيها'], ['حسابشخصي', 'اللي', 'بيسكر', 'وبعدها', 'بوقف', 'بالشاعر', 'يطخ', 'عالناس', 'بيستاهل', 'خازوق', 'عثماني،', 'ما', 'في', 'اي', 'وجه', 'للمقارنه', '.', '.'], ['حسابشخصي', 'نيالك', 'قديه', 'بالك', 'طويل']]
# Text before tokenization
# ['حسابشخصي ما بجيبا الا الزحلاوي هه', 'حسابشخصي حسابشخصي شكلك هبله وبتستهبلي علينا وفاكره هنصدقك واذا حكايتك حقيقي فابنك غبي زي اللي خلفه وانتمائه للمجرم اللي قال ان الوطن حفنه من التراب وطظ في مصر وانتم قله لا تؤثر وطظ فيكم', 'حسابشخصي 👍 اوا الله يجيب اللي يفهم', '#بلا_تشفير هلا بس تحطوا بالتابوت بدو يقول عفوك ورحمتك يا رب ويعترف بوجود الله لا شعوريا']
# Text after tokenization
# [['حسابشخصي', 'ما', 'بجيبا', 'الا', 'الزحلاوي', 'هه'], ['حسابشخصي', 'حسابشخصي', 'شكلك', 'هبله', 'وبتستهبلي', 'علينا', 'وفاكره', 'هنصدقك', 'واذا', 'حكايتك', 'حقيقي', 'فابنك', 'غبي', 'زي', 'اللي', 'خلفه', 'وانتمائه', 'للمجرم', 'اللي', 'قال', 'ان', 'الوطن', 'حفنه', 'من', 'التراب', 'وطظ', 'في', 'مصر', 'وانتم', 'قله', 'لا', 'تؤثر', 'وطظ', 'فيكم'], ['حسابشخصي', '👍', 'اوا', 'الله', 'يجيب', 'اللي', 'يفهم'], ['#', 'بلا_تشفير', 'هلا', 'بس', 'تحطوا', 'بالتابوت', 'بدو', 'يقول', 'عفوك', 'ورحمتك', 'يا', 'رب', 'ويعترف', 'بوجود', 'الله', 'لا', 'شعوريا']]

# %%
# stemmed_train_text = arabic_porter_stemmer(tokenized_train_text)
# stemmed_val_text = arabic_porter_stemmer(tokenized_val_text)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %% [markdown]
# Loading the AraVec embedding model

# %%
from gensim import *

ara_vec = models.Word2Vec.load("/content/drive/MyDrive/AraVec model/full_grams_cbow_100_twitter.mdl")
token = "مرحبا"

# %% [markdown]
# This is the embedding of the word "مرحبا " every word will have a vector size of 100

# %%
ara_vec.wv[token]
# Out:
# array([ 7.8940596e-03, -1.9478461e+00,  1.1631009e-02, -3.5182920e+00,
#        -1.2167654e+00,  3.1339860e+00,  1.5371485e+00, -1.8152795e+00,
#        -1.2115160e+00, -3.5992939e+00,  2.4862409e-01,  2.7312357e+00,
#         8.0305028e-01, -4.1077638e-01, -1.6454821e+00, -1.0270128e+00,
#         2.4021879e-01, -1.9182550e+00, -4.1562691e+00, -2.7357066e-01,
#         3.6352795e-01, -5.0566471e-01, -1.8600090e+00, -3.6048862e-01,
#         2.0769353e+00,  1.6658021e-02,  2.4419727e+00, -1.1157359e+00,
#        -1.1297592e+00, -5.2575749e-01,  5.4749495e-01,  1.1458756e+00,
#         7.8666162e-01, -2.6775408e-01,  4.9869961e-01, -9.9649131e-01,
#        -1.2755750e+00, -2.9144409e-01, -1.9790000e+00, -7.6061869e-01,
#        -2.2856839e+00, -2.2579525e+00,  1.1075810e+00,  1.2388148e+00,
#        -2.0124793e-01,  7.2702956e-01,  6.1502811e-02,  1.2161491e+00,
#         1.7231876e-01, -5.2533872e-02, -2.7908528e+00, -2.1365383e+00,
#        -1.8886662e+00,  7.3253202e-01,  4.2989811e-01,  1.0156611e+00,
#        -3.5370171e-01,  6.1726186e-02, -7.0853502e-01,  1.0767945e+00,
#        -1.2942544e+00, -3.3022109e-01,  6.0169697e-01,  1.3413342e+00,
#        -7.2281032e+00,  3.3260748e-01, -8.3516157e-01, -7.5339770e-01,
#         7.9097968e-01, -3.1070046e-03, -2.2748711e+00, -2.0984866e-01,
#        -1.4758885e+00, -2.4212074e+00,  1.8787105e+00,  1.4241277e+00,
#        -3.3634238e+00,  1.1889958e+00,  3.0775642e+00, -6.7938489e-01,
#        -2.3407989e+00,  5.1415914e-01,  2.6232326e-01, -1.2634530e+00,
#        -4.7019544e+00,  8.8880885e-01,  3.4549773e+00, -3.6733248e+00,
#         1.0713350e+00, -4.4739869e-01, -2.3007927e+00,  1.7190911e-01,
#         4.7368106e-01, -5.9018075e-01, -2.6933851e+00, -2.0220284e+00,
#         4.0170094e-01,  6.0225141e-01,  1.7372146e+00, -1.1967787e+00],
#       dtype=float32)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# import tensorflow as tf

# # Verify GPU usage
# print("GPU Available:", tf.config.list_physical_devices('GPU'))

# %%
from tensorflow import keras
from keras.preprocessing.sequence import pad_sequences
import numpy as np

def get_embedding_matrix(text_list, batch_size=10000):
    outofvocab_words = set()
    sentence_vectors = []

    for i in range(0, len(text_list), batch_size):
        batch = text_list[i:i+batch_size]

        for text in batch:
            sentence_embds = []
            for word in text:
                if word in ara_vec.wv:
                    sentence_embds.append(ara_vec.wv[word])
                else:
                    outofvocab_words.add(word)
            if sentence_embds:
                sentence_vector = np.mean(sentence_embds, axis=0)  # Average over words
            else:
                sentence_vector = np.zeros(ara_vec.vector_size)  # Handle empty sentences

            sentence_vectors.append(sentence_vector)

    print(f"Number of Out Of Vocab words: {len(outofvocab_words)}")
    print(f"Embedded text shape: {np.array(sentence_vectors).shape}")

    return np.array(sentence_vectors)

# %% [markdown]
# Embbeding

# %%
x_train_embds = get_embedding_matrix(tokenized_train_text, 64)
# Out:
# Number of Out Of Vocab words: 147426
# Embedded text shape: (352041, 64, 100)

# %%
x_val_embds = get_embedding_matrix(tokenized_val_text, 64)
# Out:
# Number of Out Of Vocab words: 21903
# Embedded text shape: (44005, 64, 100)

# %%
x_test = x_test["text"]

# %%
x_test_tokenized = treebank_tokenization(x_test)
# Out:
# Text before tokenization
# ['الفلوس مش كل حاجه بدليل هلك ماخدش منك اجار دارك 🤔 ', 'حسابشخصي حسابشخصي 😂 ولكن هنا فالمغرب الامازيغيه كفكر مرتبطه بلاطلس المتوسط كاينين كلمات كتسمعهم كيكونو خاصين بالمنطقه عاد ديك الساعه كتعمم', 'حسابشخصي في ناس تستاهل اكتر من كده', 'حسابشخصي حسابشخصي انا شخصيا احب اعرف ندي راحه فين ؟ ؟ 😂 ']
# Text after tokenization
# [['الفلوس', 'مش', 'كل', 'حاجه', 'بدليل', 'هلك', 'ماخدش', 'منك', 'اجار', 'دارك', '🤔'], ['حسابشخصي', 'حسابشخصي', '😂', 'ولكن', 'هنا', 'فالمغرب', 'الامازيغيه', 'كفكر', 'مرتبطه', 'بلاطلس', 'المتوسط', 'كاينين', 'كلمات', 'كتسمعهم', 'كيكونو', 'خاصين', 'بالمنطقه', 'عاد', 'ديك', 'الساعه', 'كتعمم'], ['حسابشخصي', 'في', 'ناس', 'تستاهل', 'اكتر', 'من', 'كده'], ['حسابشخصي', 'حسابشخصي', 'انا', 'شخصيا', 'احب', 'اعرف', 'ندي', 'راحه', 'فين', '؟', '؟', '😂']]

# %%
x_test = get_embedding_matrix(x_test_tokenized, 64)
# Out:
# Number of Out Of Vocab words: 21874
# Embedded text shape: (44006, 64, 100)

# %%
x_train_embds.shape
# Out:
# (352041, 64, 100)

# %%
x_val_embds.shape
# Out:
# (44005, 64, 100)

# %%
# y_train = y_train.astype("int32")
# x_train_embds = x_train_embds.reshape(x_train_embds.shape[0], 64, 100)
# x_val_embds = x_val_embds.reshape(x_val_embds.shape[0], 64, 100)
# print(y_train.shape)
# Out:
# (92000,)

# %% [markdown]
# Tokenizing and Embedding of the testing sample to calculate F1-score down bellow after each model

# %% [markdown]
# Models

# %% [markdown]
# Note: There are two callbacks used one of them is early stopping which stops training the model if the validation loss didn't improve for (if patience=5) 5 epochs since the best validation reached
#
# model checkpoint saves the model when reaching better weights and continues training

# %% [markdown]
# LSTM_100 batch size 128 36 f1 score

# %%
from keras import layers
from tensorflow.keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

lstm_model = keras.models.Sequential([
    layers.Input(shape=(64, 100)),
    LSTM(128, return_sequences=True),
    LSTM(64, return_sequences=False),
    layers.Dropout(0.4),
    layers.Dense(64, activation="relu", kernel_regularizer="l2"),
    layers.Dense(18, activation="softmax"),
])

lstm_model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("LSTm_100.keras", save_best_only=True, monitor="val_loss", verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
history = lstm_model.fit(x_train_embds, y_train, batch_size=128, epochs=20, validation_data=(x_val_embds, y_val), callbacks=[checkpoint, early_stopping])
lstm_model.save("LSTm_100.h5")
# Out:
# Epoch 1/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.1676 - loss: 2.8728
# Epoch 1: val_loss improved from inf to 2.41612, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.1678 - loss: 2.8715 - val_accuracy: 0.2189 - val_loss: 2.4161
# Epoch 2/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2442 - loss: 2.3533
# Epoch 2: val_loss improved from 2.41612 to 2.28908, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.2443 - loss: 2.3532 - val_accuracy: 0.2544 - val_loss: 2.2891
# Epoch 3/20
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2622 - loss: 2.2569
# Epoch 3: val_loss improved from 2.28908 to 2.20206, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.2623 - loss: 2.2569 - val_accuracy: 0.2769 - val_loss: 2.2021
# Epoch 4/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2830 - loss: 2.1831
# Epoch 4: val_loss improved from 2.20206 to 2.10703, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.2830 - loss: 2.1831 - val_accuracy: 0.3115 - val_loss: 2.1070
# Epoch 5/20
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3158 - loss: 2.0933
# Epoch 5: val_loss improved from 2.10703 to 2.06631, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.3158 - loss: 2.0932 - val_accuracy: 0.3254 - val_loss: 2.0663
# Epoch 6/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3376 - loss: 2.0267
# Epoch 6: val_loss improved from 2.06631 to 2.04699, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.3376 - loss: 2.0267 - val_accuracy: 0.3376 - val_loss: 2.0470
# Epoch 7/20
# 715/719 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3611 - loss: 1.9711
# Epoch 7: val_loss improved from 2.04699 to 1.97212, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.3612 - loss: 1.9710 - val_accuracy: 0.3567 - val_loss: 1.9721
# Epoch 8/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3835 - loss: 1.8949
# Epoch 8: val_loss improved from 1.97212 to 1.92455, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.3835 - loss: 1.8949 - val_accuracy: 0.3819 - val_loss: 1.9246
# Epoch 9/20
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4030 - loss: 1.8495
# Epoch 9: val_loss improved from 1.92455 to 1.90023, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.4030 - loss: 1.8495 - val_accuracy: 0.3923 - val_loss: 1.9002
# Epoch 10/20
# 715/719 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4243 - loss: 1.7918
# Epoch 10: val_loss improved from 1.90023 to 1.88650, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4243 - loss: 1.7919 - val_accuracy: 0.4019 - val_loss: 1.8865
# Epoch 11/20
# 715/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4363 - loss: 1.7541
# Epoch 11: val_loss improved from 1.88650 to 1.87514, saving model to LSTm_100.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.4362 - loss: 1.7542 - val_accuracy: 0.4058 - val_loss: 1.8751
# Epoch 12/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4521 - loss: 1.6980
# Epoch 12: val_loss did not improve from 1.87514
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.4521 - loss: 1.6981 - val_accuracy: 0.4083 - val_loss: 1.8775
# Epoch 13/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4656 - loss: 1.6673
# Epoch 13: val_loss did not improve from 1.87514
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.4656 - loss: 1.6673 - val_accuracy: 0.4061 - val_loss: 1.8799
# Epoch 14/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4768 - loss: 1.6208
# Epoch 14: val_loss did not improve from 1.87514
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.4768 - loss: 1.6209 - val_accuracy: 0.4110 - val_loss: 1.8804
# Epoch 15/20
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4897 - loss: 1.5836
# Epoch 15: val_loss did not improve from 1.87514
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.4897 - loss: 1.5836 - val_accuracy: 0.4129 - val_loss: 1.8995
# Epoch 16/20
# 717/719 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5002 - loss: 1.5520
# Epoch 16: val_loss did not improve from 1.87514
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.5002 - loss: 1.5520 - val_accuracy: 0.4137 - val_loss: 1.8936
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import f1_score
y_pred = np.argmax(lstm_model.predict(x_test), axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class, 'binary' for binary
print("F1-Score:", round(f1, 5))
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# F1-Score: 0.367

# %% [markdown]
# LSTM_2 batch size 256 42 f1-score

# %%
from keras import layers
from tensorflow.keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

lstm_model2 = keras.models.Sequential([
    layers.Input(shape=(64, 100)),
    LSTM(256, return_sequences=True),
    LSTM(128, return_sequences=False),
    layers.Dropout(0.2),
    layers.Dense(18, activation="softmax"),
])

lstm_model2.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.0004), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("LSTM_2.keras", save_best_only=True, monitor="val_loss", verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
history = lstm_model2.fit(x_train_embds, y_train, batch_size=128, epochs=20, validation_data=(x_val_embds, y_val), callbacks=[checkpoint, early_stopping])
lstm_model2.save("LSTM_2.h5")
# Out:
# Epoch 1/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2066 - loss: 2.4790
# Epoch 1: val_loss improved from inf to 2.15180, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - accuracy: 0.2069 - loss: 2.4782 - val_accuracy: 0.2943 - val_loss: 2.1518
# Epoch 2/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3080 - loss: 2.1004
# Epoch 2: val_loss improved from 2.15180 to 1.97563, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.3080 - loss: 2.1003 - val_accuracy: 0.3521 - val_loss: 1.9756
# Epoch 3/20
# 717/719 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3677 - loss: 1.9528
# Epoch 3: val_loss improved from 1.97563 to 1.88946, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - accuracy: 0.3677 - loss: 1.9527 - val_accuracy: 0.3956 - val_loss: 1.8895
# Epoch 4/20
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4021 - loss: 1.8519
# Epoch 4: val_loss improved from 1.88946 to 1.85142, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.4021 - loss: 1.8519 - val_accuracy: 0.4045 - val_loss: 1.8514
# Epoch 5/20
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4273 - loss: 1.7823
# Epoch 5: val_loss improved from 1.85142 to 1.82583, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.4273 - loss: 1.7823 - val_accuracy: 0.4172 - val_loss: 1.8258
# Epoch 6/20
# 717/719 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4464 - loss: 1.7216
# Epoch 6: val_loss improved from 1.82583 to 1.78503, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.4464 - loss: 1.7216 - val_accuracy: 0.4316 - val_loss: 1.7850
# Epoch 7/20
# 717/719 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4686 - loss: 1.6621
# Epoch 7: val_loss improved from 1.78503 to 1.76920, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.4686 - loss: 1.6621 - val_accuracy: 0.4373 - val_loss: 1.7692
# Epoch 8/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4905 - loss: 1.5944
# Epoch 8: val_loss improved from 1.76920 to 1.75670, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.4905 - loss: 1.5944 - val_accuracy: 0.4463 - val_loss: 1.7567
# Epoch 9/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5071 - loss: 1.5427
# Epoch 9: val_loss improved from 1.75670 to 1.74915, saving model to LSTM_2.keras
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.5071 - loss: 1.5427 - val_accuracy: 0.4476 - val_loss: 1.7491
# Epoch 10/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5235 - loss: 1.4892
# Epoch 10: val_loss did not improve from 1.74915
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.5235 - loss: 1.4893 - val_accuracy: 0.4563 - val_loss: 1.7609
# Epoch 11/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5376 - loss: 1.4400
# Epoch 11: val_loss did not improve from 1.74915
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.5376 - loss: 1.4401 - val_accuracy: 0.4544 - val_loss: 1.7740
# Epoch 12/20
# 718/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5594 - loss: 1.3839
# Epoch 12: val_loss did not improve from 1.74915
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.5593 - loss: 1.3839 - val_accuracy: 0.4537 - val_loss: 1.7790
# Epoch 13/20
# 717/719 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5784 - loss: 1.3267
# Epoch 13: val_loss did not improve from 1.74915
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5784 - loss: 1.3268 - val_accuracy: 0.4484 - val_loss: 1.8281
# Epoch 14/20
# 716/719 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5961 - loss: 1.2674
# Epoch 14: val_loss did not improve from 1.74915
# 719/719 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.5961 - loss: 1.2676 - val_accuracy: 0.4556 - val_loss: 1.8566
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# just changing differrent names of models to save

# %%
from sklearn.metrics import f1_score
y_pred = np.argmax(lstm_model2.predict(x_test), axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class, 'binary' for binary
print("F1-Score:", f1)
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# F1-Score: 0.4228627849918556

# %% [markdown]
# LSTM_3.h5

# %%
from keras import layers
from tensorflow.keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

lstm_model3 = keras.models.Sequential([
    layers.Input(shape=(64, 100)),
    LSTM(256, return_sequences=True, recurrent_dropout=0.2),
    LSTM(128, return_sequences=False, recurrent_dropout=0.2),
    layers.Dropout(0.2),
    layers.Dense(18, activation="softmax"),
])

lstm_model3.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.0004), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("LSTM_3.keras", save_best_only=True, monitor="val_loss", verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
history = lstm_model2.fit(x_train_embds, y_train, batch_size=256, epochs=20, validation_data=(x_val_embds, y_val), callbacks=[checkpoint, early_stopping])
lstm_model2.save("LSTM_3.h5")

# %%
lstm_model2.save("LSTM_2.h5")

# %% [markdown]
# LSTM with self attention 2

# %%
from keras import layers, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, BatchNormalization, Attention
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

inputs = layers.Input(shape=(64, 100))
lstm_layer = LSTM(256, return_sequences=True, recurrent_dropout=0.2)(inputs)
lstm_attention = Attention()([lstm_layer, lstm_layer])
lstm2_layer = LSTM(128, return_sequences=False)(lstm_attention)
model_layers = Dropout(0.4)(lstm2_layer)
outputs = Dense(18, activation="softmax")(model_layers)

lstm_model5 = Model(inputs=inputs, outputs=outputs)

lstm_model5.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.0004), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("LSTm_selfattention2.keras", save_best_only=True, monitor="val_loss", verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
history = lstm_model5.fit(x_train_embds, y_train, batch_size=256, epochs=20, validation_data=(x_val_embds, y_val), callbacks=[checkpoint, early_stopping])
lstm_model5.save("LSTm_selfattention2.h5")
# Out:
# Epoch 1/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.2532 - loss: 2.3680
# Epoch 1: val_loss improved from inf to 1.92426, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 52s 122ms/step - accuracy: 0.2533 - loss: 2.3675 - val_accuracy: 0.3777 - val_loss: 1.9243
# Epoch 2/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3811 - loss: 1.9275
# Epoch 2: val_loss improved from 1.92426 to 1.81333, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 74s 112ms/step - accuracy: 0.3811 - loss: 1.9275 - val_accuracy: 0.4182 - val_loss: 1.8133
# Epoch 3/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4159 - loss: 1.8236
# Epoch 3: val_loss improved from 1.81333 to 1.74699, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 39s 107ms/step - accuracy: 0.4159 - loss: 1.8235 - val_accuracy: 0.4357 - val_loss: 1.7470
# Epoch 4/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4443 - loss: 1.7418
# Epoch 4: val_loss improved from 1.74699 to 1.72043, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 44s 117ms/step - accuracy: 0.4443 - loss: 1.7418 - val_accuracy: 0.4502 - val_loss: 1.7204
# Epoch 5/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.4647 - loss: 1.6801
# Epoch 5: val_loss improved from 1.72043 to 1.68205, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 40s 111ms/step - accuracy: 0.4647 - loss: 1.6801 - val_accuracy: 0.4574 - val_loss: 1.6821
# Epoch 6/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4793 - loss: 1.6338
# Epoch 6: val_loss improved from 1.68205 to 1.67751, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 40s 111ms/step - accuracy: 0.4793 - loss: 1.6337 - val_accuracy: 0.4633 - val_loss: 1.6775
# Epoch 7/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4956 - loss: 1.5847
# Epoch 7: val_loss improved from 1.67751 to 1.67040, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 42s 113ms/step - accuracy: 0.4956 - loss: 1.5847 - val_accuracy: 0.4626 - val_loss: 1.6704
# Epoch 8/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5121 - loss: 1.5349
# Epoch 8: val_loss improved from 1.67040 to 1.64462, saving model to LSTm_selfattention2.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 41s 112ms/step - accuracy: 0.5121 - loss: 1.5349 - val_accuracy: 0.4749 - val_loss: 1.6446
# Epoch 9/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5288 - loss: 1.4913
# Epoch 9: val_loss did not improve from 1.64462
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 43s 117ms/step - accuracy: 0.5288 - loss: 1.4913 - val_accuracy: 0.4770 - val_loss: 1.6450
# Epoch 10/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5417 - loss: 1.4455
# Epoch 10: val_loss did not improve from 1.64462
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 81s 115ms/step - accuracy: 0.5416 - loss: 1.4456 - val_accuracy: 0.4735 - val_loss: 1.6562
# Epoch 11/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5584 - loss: 1.4057
# Epoch 11: val_loss did not improve from 1.64462
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 83s 119ms/step - accuracy: 0.5583 - loss: 1.4057 - val_accuracy: 0.4737 - val_loss: 1.6987
# Epoch 12/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5692 - loss: 1.3688
# Epoch 12: val_loss did not improve from 1.64462
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 79s 110ms/step - accuracy: 0.5692 - loss: 1.3688 - val_accuracy: 0.4785 - val_loss: 1.6709
# Epoch 13/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5858 - loss: 1.3225
# Epoch 13: val_loss did not improve from 1.64462
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 42s 112ms/step - accuracy: 0.5858 - loss: 1.3225 - val_accuracy: 0.4791 - val_loss: 1.7127
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import f1_score
y_pred = np.argmax(lstm_model5.predict(x_test), axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class, 'binary' for binary
print("F1-Score:", f1)
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step
# F1-Score: 0.4542038019815656

# %%
from sklearn.metrics import f1_score
y_pred = np.argmax(lstm_model5.predict(x_test), axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class, 'binary' for binary
print("F1-Score:", f1)

# %% [markdown]
# LSTM self attention batch size 128 (best)

# %%
from keras import layers, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, BatchNormalization, Attention
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

inputs = layers.Input(shape=(64, 100))
lstm_layer = LSTM(256, return_sequences=True, recurrent_dropout=0.2)(inputs)
lstm_attention = Attention()([lstm_layer, lstm_layer])
lstm2_layer = LSTM(128, return_sequences=False)(lstm_attention)
model_layers = Dropout(0.4)(lstm2_layer)
outputs = Dense(18, activation="softmax")(model_layers)

lstm_model5 = Model(inputs=inputs, outputs=outputs)

lstm_model5.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.0004), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("LSTm_selfattention2.keras", save_best_only=True, monitor="val_loss", verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True)
history = lstm_model5.fit(x_train_embds, y_train, batch_size=256, epochs=20, validation_data=(x_val_embds, y_val), callbacks=[checkpoint, early_stopping])
lstm_model5.save("LSTM_alldata.h5")
# Out:
# Epoch 1/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3281 - loss: 2.1103
# Epoch 1: val_loss improved from inf to 1.72221, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 95s 66ms/step - accuracy: 0.3281 - loss: 2.1102 - val_accuracy: 0.4474 - val_loss: 1.7222
# Epoch 2/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4514 - loss: 1.7212
# Epoch 2: val_loss improved from 1.72221 to 1.62520, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.4514 - loss: 1.7212 - val_accuracy: 0.4803 - val_loss: 1.6252
# Epoch 3/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4851 - loss: 1.6200
# Epoch 3: val_loss improved from 1.62520 to 1.59091, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.4852 - loss: 1.6200 - val_accuracy: 0.4919 - val_loss: 1.5909
# Epoch 4/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5073 - loss: 1.5554
# Epoch 4: val_loss improved from 1.59091 to 1.55785, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.5073 - loss: 1.5554 - val_accuracy: 0.5041 - val_loss: 1.5579
# Epoch 5/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5238 - loss: 1.5066
# Epoch 5: val_loss improved from 1.55785 to 1.53526, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.5238 - loss: 1.5066 - val_accuracy: 0.5115 - val_loss: 1.5353
# Epoch 6/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5342 - loss: 1.4685
# Epoch 6: val_loss improved from 1.53526 to 1.52137, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 64ms/step - accuracy: 0.5342 - loss: 1.4685 - val_accuracy: 0.5152 - val_loss: 1.5214
# Epoch 7/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5491 - loss: 1.4287
# Epoch 7: val_loss did not improve from 1.52137
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.5491 - loss: 1.4287 - val_accuracy: 0.5182 - val_loss: 1.5233
# Epoch 8/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5577 - loss: 1.3991
# Epoch 8: val_loss improved from 1.52137 to 1.51587, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 64ms/step - accuracy: 0.5577 - loss: 1.3991 - val_accuracy: 0.5192 - val_loss: 1.5159
# Epoch 9/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5665 - loss: 1.3746
# Epoch 9: val_loss improved from 1.51587 to 1.51348, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.5665 - loss: 1.3746 - val_accuracy: 0.5217 - val_loss: 1.5135
# Epoch 10/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5766 - loss: 1.3402
# Epoch 10: val_loss did not improve from 1.51348
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.5766 - loss: 1.3402 - val_accuracy: 0.5159 - val_loss: 1.5235
# Epoch 11/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5853 - loss: 1.3202
# Epoch 11: val_loss improved from 1.51348 to 1.50980, saving model to LSTm_selfattention2.keras
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 65ms/step - accuracy: 0.5853 - loss: 1.3202 - val_accuracy: 0.5243 - val_loss: 1.5098
# Epoch 12/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5907 - loss: 1.2989
# Epoch 12: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 64ms/step - accuracy: 0.5907 - loss: 1.2989 - val_accuracy: 0.5243 - val_loss: 1.5197
# Epoch 13/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5976 - loss: 1.2795
# Epoch 13: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 90s 65ms/step - accuracy: 0.5976 - loss: 1.2795 - val_accuracy: 0.5263 - val_loss: 1.5306
# Epoch 14/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6055 - loss: 1.2560
# Epoch 14: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 88s 64ms/step - accuracy: 0.6055 - loss: 1.2560 - val_accuracy: 0.5247 - val_loss: 1.5346
# Epoch 15/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6121 - loss: 1.2334
# Epoch 15: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 64ms/step - accuracy: 0.6121 - loss: 1.2334 - val_accuracy: 0.5235 - val_loss: 1.5414
# Epoch 16/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6178 - loss: 1.2219
# Epoch 16: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 65ms/step - accuracy: 0.6178 - loss: 1.2219 - val_accuracy: 0.5236 - val_loss: 1.5460
# Epoch 17/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6246 - loss: 1.2001
# Epoch 17: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 65ms/step - accuracy: 0.6246 - loss: 1.2001 - val_accuracy: 0.5250 - val_loss: 1.5450
# Epoch 18/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6271 - loss: 1.1912
# Epoch 18: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 64ms/step - accuracy: 0.6271 - loss: 1.1912 - val_accuracy: 0.5227 - val_loss: 1.5748
# Epoch 19/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6336 - loss: 1.1743
# Epoch 19: val_loss did not improve from 1.50980
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 89s 64ms/step - accuracy: 0.6336 - loss: 1.1743 - val_accuracy: 0.5220 - val_loss: 1.5785
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import f1_score
y_pred = np.argmax(lstm_model5.predict(x_test), axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class, 'binary' for binary
print("F1-Score:", f1)
# Out:
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 35s 25ms/step
# F1-Score: 0.5142155836369434

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

lstm = keras.models.load_model("/content/LSTM_alldata.h5")
y_pred = np.argmax(lstm_model5.predict(x_test), axis=1)

if y_test.ndim > 1:  # Check if one-hot encoded
    y_test = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_test, y_pred)

classes = ["AE", "BH", "DZ", "EG", "IQ", "JO", "KW", "LB", "LY", "MA", "OM", "PL", "QA", "SA", "SD", "SY", "TN", "YE"]
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Step 6: Optional: Print detailed classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 34s 25ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           AE       0.37      0.35      0.36      1836
#           BH       0.68      0.55      0.61      1386
#           DZ       0.40      0.48      0.44      2577
#           EG       0.46      0.60      0.52      4044
#           IQ       0.51      0.35      0.42      2984
#           JO       0.57      0.64      0.60      2653
#           KW       0.42      0.29      0.34      2682
#           LB       0.47      0.31      0.37      1560
#           LY       0.60      0.49      0.54      1488
#           MA       0.65      0.59      0.62      1108
#           OM       0.70      0.89      0.78      5536
#           PL       0.52      0.53      0.52      4201
#           QA       0.40      0.18      0.25       953
#           SA       0.32      0.36      0.34      2525
#           SD       0.58      0.49      0.53      1554
#           SY       0.37      0.39      0.38      2525
#           TN       0.57      0.42      0.48       888
#           YE       0.64      0.62      0.63      3506
#
#     accuracy                           0.52     44006
#    macro avg       0.51      0.47      0.49     44006
# weighted avg       0.52      0.52      0.51     44006

# %% [markdown]
# LSTM self attention 22

# %%
from keras import layers, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, BatchNormalization, Attention
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

inputs = layers.Input(shape=(64, 100))
lstm_layer = LSTM(256, return_sequences=True, recurrent_dropout=0.2)(inputs)
lstm_attention = Attention()([lstm_layer, lstm_layer])
lstm2_layer = LSTM(128, return_sequences=False, recurrent_dropout=0.2)(lstm_attention)
model_layers = Dropout(0.2)(lstm2_layer)
outputs = Dense(18, activation="softmax")(model_layers)

lstm_model52 = Model(inputs=inputs, outputs=outputs)

lstm_model52.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(learning_rate=0.0005), metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("LSTm_selfattention22.keras", save_best_only=True, monitor="val_loss", verbose=1)
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
history = lstm_model52.fit(x_train_embds, y_train, batch_size=256, epochs=20, validation_data=(x_val_embds, y_val), callbacks=[checkpoint, early_stopping])
lstm_model52.save("LSTm_selfattention22.h5")
# Out:
# Epoch 1/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.2701 - loss: 2.3057
# Epoch 1: val_loss improved from inf to 1.88072, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 84s 206ms/step - accuracy: 0.2703 - loss: 2.3052 - val_accuracy: 0.3928 - val_loss: 1.8807
# Epoch 2/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3954 - loss: 1.8786
# Epoch 2: val_loss improved from 1.88072 to 1.76794, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 79s 209ms/step - accuracy: 0.3954 - loss: 1.8785 - val_accuracy: 0.4329 - val_loss: 1.7679
# Epoch 3/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.4308 - loss: 1.7687
# Epoch 3: val_loss improved from 1.76794 to 1.71050, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 83s 211ms/step - accuracy: 0.4308 - loss: 1.7687 - val_accuracy: 0.4493 - val_loss: 1.7105
# Epoch 4/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.4615 - loss: 1.6797
# Epoch 4: val_loss improved from 1.71050 to 1.67868, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 79s 203ms/step - accuracy: 0.4615 - loss: 1.6797 - val_accuracy: 0.4614 - val_loss: 1.6787
# Epoch 5/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.4807 - loss: 1.6229
# Epoch 5: val_loss improved from 1.67868 to 1.64598, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 82s 205ms/step - accuracy: 0.4807 - loss: 1.6229 - val_accuracy: 0.4736 - val_loss: 1.6460
# Epoch 6/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.5036 - loss: 1.5591
# Epoch 6: val_loss improved from 1.64598 to 1.64557, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 82s 204ms/step - accuracy: 0.5036 - loss: 1.5591 - val_accuracy: 0.4735 - val_loss: 1.6456
# Epoch 7/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.5154 - loss: 1.5130
# Epoch 7: val_loss improved from 1.64557 to 1.63062, saving model to LSTm_selfattention22.keras
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 83s 208ms/step - accuracy: 0.5154 - loss: 1.5131 - val_accuracy: 0.4751 - val_loss: 1.6306
# Epoch 8/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.5304 - loss: 1.4650
# Epoch 8: val_loss did not improve from 1.63062
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 81s 206ms/step - accuracy: 0.5304 - loss: 1.4650 - val_accuracy: 0.4789 - val_loss: 1.6351
# Epoch 9/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.5498 - loss: 1.4091
# Epoch 9: val_loss did not improve from 1.63062
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 80s 203ms/step - accuracy: 0.5498 - loss: 1.4092 - val_accuracy: 0.4788 - val_loss: 1.6381
# Epoch 10/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5636 - loss: 1.3604
# Epoch 10: val_loss did not improve from 1.63062
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 83s 205ms/step - accuracy: 0.5636 - loss: 1.3604 - val_accuracy: 0.4762 - val_loss: 1.6651
# Epoch 11/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.5790 - loss: 1.3258
# Epoch 11: val_loss did not improve from 1.63062
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 83s 207ms/step - accuracy: 0.5790 - loss: 1.3258 - val_accuracy: 0.4741 - val_loss: 1.6808
# Epoch 12/20
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5938 - loss: 1.2731
# Epoch 12: val_loss did not improve from 1.63062
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 84s 214ms/step - accuracy: 0.5937 - loss: 1.2731 - val_accuracy: 0.4742 - val_loss: 1.7068
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import f1_score
y_pred = np.argmax(lstm_model52.predict(x_test), axis=1)
f1 = f1_score(y_test, y_pred, average='weighted')  # 'weighted' for multi-class, 'binary' for binary
print("F1-Score:", f1)
# Out:
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 51ms/step
# F1-Score: 0.4617611139295703

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

lstm = keras.models.load_model("LSTm_selfattention22.h5")
y_pred = np.argmax(lstm_model52.predict(x_test), axis=1)

if y_test.ndim > 1:  # Check if one-hot encoded
    y_test = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_test, y_pred)

classes = ["AE", "BH", "DZ", "EG", "IQ", "JO", "KW", "LB", "LY", "MA", "OM", "PL", "QA", "SA", "SD", "SY", "TN", "YE"]
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Step 6: Optional: Print detailed classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#           AE       0.33      0.27      0.30       469
#           BH       0.66      0.46      0.54       369
#           DZ       0.36      0.43      0.39       669
#           EG       0.43      0.56      0.48      1041
#           IQ       0.39      0.38      0.39       772
#           JO       0.53      0.58      0.55       682
#           KW       0.31      0.14      0.19       697
#           LB       0.48      0.14      0.22       415
#           LY       0.61      0.45      0.52       401
#           MA       0.65      0.51      0.57       296
#           OM       0.72      0.87      0.79      1445
#           PL       0.41      0.61      0.49      1119
#           QA       0.35      0.18      0.24       245
#           SA       0.29      0.31      0.30       667
#           SD       0.54      0.37      0.44       406
#           SY       0.38      0.28      0.32       662
#           TN       0.48      0.26      0.34       230
#           YE       0.52      0.62      0.56       915
#
#     accuracy                           0.48     11500
#    macro avg       0.47      0.41      0.42     11500
# weighted avg       0.47      0.48      0.46     11500

# %% [markdown]
# LSTM self attention

# %%
# saved_file_limitization = "dataset_preprocessed_limitization.csv"
# _ = arabic_preprocess_pipline(original_file, saved_file_limitization, id_col, text_c, dialects_col, labels_encoded=False ,using_lemma=True)
